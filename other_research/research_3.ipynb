# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('research3.csv')
df
# Out:
#       iid   id  partner  pid  match  field_cd
# 0      12  2.0        1    1      0         1
# 1      13  3.0        1    1      1         1
# 2      14  4.0        1    1      1         1
# 3      15  5.0        1    1      1         1
# 4      12  2.0        2    2      0         1
# 5      13  3.0        2    2      0         1
# 6      14  4.0        2    2      1         1
# 7      15  5.0        2    2      0         1
# 8      12  2.0        3    3      0         1
# 9      13  3.0        3    3      0         1
# 10     14  4.0        3    3      0         1
# 11     15  5.0        3    3      0         1
# 12     12  2.0        4    4      0         1
# 13     13  3.0        4    4      0         1
# 14     14  4.0        4    4      1         1
# 15     15  5.0        4    4      0         1
# 16     12  2.0        5    5      0         1
# 17     13  3.0        5    5      0         1
# 18     14  4.0        5    5      1         1
# ...

# %%
A=df.loc[df['field_cd'].isin([2,4,10])]
A['field_cd']='Natural Science/Medical'

B=df.loc[df['field_cd'].isin([1])]
B['field_cd']='Law'

C=df.loc[df['field_cd'].isin([3,9,11,13])]
C['field_cd']='Social Science'

D=df.loc[df['field_cd'].isin([5])]
D['field_cd']='Engineering'

E=df.loc[df['field_cd'].isin([6,7,16])]
E['field_cd']='Liberal Arts'

F=df.loc[df['field_cd'].isin([8])]
F['field_cd']='Business/Finance'

G=df.loc[df['field_cd'].isin([12,14,15,17,18])]
G['field_cd']='Arts'
# Out:
# /Users/lexiewen/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/lexiewen/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/lexiewen/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dff = [A, B, C,D,E,F,G]
df_f= pd.concat(dff)
df_field_iid=df_f.drop(['id','partner','pid','match'],axis=1)
df_field_iid.to_csv('fieldname.csv')

# %%
df_f
# Out:
#       iid    id  partner  pid  match                 field_cd
# 664     3   3.0        1   11      0  Natural Science/Medical
# 665     3   3.0        2   12      0  Natural Science/Medical
# 666     3   3.0        3   13      0  Natural Science/Medical
# 667     3   3.0        4   14      0  Natural Science/Medical
# 668     3   3.0        5   15      0  Natural Science/Medical
# 669     3   3.0        6   16      0  Natural Science/Medical
# 670     3   3.0        7   17      0  Natural Science/Medical
# 671     3   3.0        8   18      0  Natural Science/Medical
# 672     3   3.0        9   19      0  Natural Science/Medical
# 673     3   3.0       10   20      0  Natural Science/Medical
# 674    35  15.0        1   40      0  Natural Science/Medical
# 675    36  16.0        1   40      0  Natural Science/Medical
# 676    35  15.0        2   41      0  Natural Science/Medical
# 677    36  16.0        2   41      0  Natural Science/Medical
# ...

# %%
df_key=pd.read_csv('fieldname_update.csv')
df_key
# Out:
#      iid                 field_cd
# 0      1                      Law
# 1      2                      Law
# 2      3  Natural Science/Medical
# 3      4                      Law
# 4      5                      Law
# 5      6                      Law
# 6      7                      Law
# 7      8           Social Science
# 8      9           Social Science
# 9     10           Social Science
# 10    11         Business/Finance
# 11    12                      Law
# 12    13                      Law
# 13    14                      Law
# 14    15                      Law
# 15    16         Business/Finance
# 16    17           Social Science
# 17    18         Business/Finance
# 18    19         Business/Finance
# 19    20         Business/Finance
# 20    21              Engineering
# 21    22           Social Science
# 22    23           Social Science
# 23    24           Social Science
# 24    25           Social Science
# 25    26           Social Science
# ...

# %%
df_key=pd.read_csv('fieldname_update.csv')
field_dict=dict()
for i in range(0,len(df_key['iid'])):
    field_dict[df_key['iid'][i]]=df_key['field_cd'][i]
field_dict[40]='Law'
field_dict[58]='Social Science'
field_dict[59]='Social Science'
field_dict[118]='Liberal Arts'
field_dict[136]='Business/Finance'
field_dict[339]='Engineering'
field_dict[340]='Social Science'
field_dict[346]='Social Science'

# %%
df_f=df_f.sort_index(ascending=True)
df_f['field_pcd']=''
#name=list()
#a=0
for i in range(0,len(df_f['pid'])):
    n=df_f['pid'][i]
    df_f['field_pcd'][i]=field_dict[n]
        
df_f
# Out:
# /Users/lexiewen/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       iid   id  partner  pid  match          field_cd                field_pcd
# 0      12  2.0        1    1      0               Law                      Law
# 1      13  3.0        1    1      1               Law                      Law
# 2      14  4.0        1    1      1               Law                      Law
# 3      15  5.0        1    1      1               Law                      Law
# 4      12  2.0        2    2      0               Law                      Law
# 5      13  3.0        2    2      0               Law                      Law
# 6      14  4.0        2    2      1               Law                      Law
# ...

# %%
df_f=df_f.loc[df_f['match'].isin([1])]
df_f.index=range(1380)
df_f
# Out:
#       iid    id  partner  pid  match                 field_cd
# 0      35  15.0        6   45      1  Natural Science/Medical
# 1      35  15.0        7   46      1  Natural Science/Medical
# 2      35  15.0       10   49      1  Natural Science/Medical
# 3      36  16.0       10   49      1  Natural Science/Medical
# 4      35  15.0       11   50      1  Natural Science/Medical
# 5      36  16.0       12   51      1  Natural Science/Medical
# 6      35  15.0       14   53      1  Natural Science/Medical
# 7     173  16.0        1  142      1  Natural Science/Medical
# 8     173  16.0        8  149      1  Natural Science/Medical
# 9     173  16.0       10  151      1  Natural Science/Medical
# 10    173  16.0       13  154      1  Natural Science/Medical
# 11    173  16.0       15  156      1  Natural Science/Medical
# 12    185   2.0        8  181      1  Natural Science/Medical
# 13    202   9.0        4  217      1  Natural Science/Medical
# ...

# %%
Final=pd.read_csv('heatmap.csv')
Final
# Out:
#     Amount            Field          Field_p
# 0       36             Law              Law
# 1       21             Law          Business
# 2       40             Law    Social Science
# 3        5             Law              Arts
# 4        3             Law       Engineering
# 5        8             Law      Liberal Arts
# 6        9             Law   Natural Science
# 7       40   Social Science             Law
# 8       76   Social Science   Social Science
# 9      135   Social Science         Business
# 10      13   Social Science             Arts
# 11      43   Social Science      Engineering
# 12      23   Social Science     Liberal Arts
# 13      44   Social Science  Natural Science
# 14       7  Natural Science             Law
# 15      44  Natural Science   Social Science
# 16      56  Natural Science         Business
# 17       8  Natural Science             Arts
# 18      21  Natural Science      Engineering
# 19       8  Natural Science     Liberal Arts
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set()

# Load the example flights dataset and conver to long-form
#flights_long = sns.load_dataset("flights")
#flights_long
Fields = Final.pivot("Field", "Field_p", "Amount")

sns.heatmap(Fields, fmt="d")
#plt.a(figsize=(20,10))
plt.savefig('./heatmap.png',dpi=300,bbox_inches='tight')
#help(plt.savefig)

#sns_plot.savefig("output.png")
# Draw a heatmap with the numeric values in each cell
#sns.heatmap(Fields, annot=True, fmt="d", linewidths=.5)

# %%
help(sns.heatmap)
# Out:
# Help on function heatmap in module seaborn.matrix:
#
# heatmap(data, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, ax=None, xticklabels=True, yticklabels=True, mask=None, **kwargs)
#     Plot rectangular data as a color-encoded matrix.
#
#     This function tries to infer a good colormap to use from the data, but
#     this is not guaranteed to work, so take care to make sure the kind of
#     colormap (sequential or diverging) and its limits are appropriate.
#
#     This is an Axes-level function and will draw the heatmap into the
#     currently-active Axes if none is provided to the ``ax`` argument.  Part of
#     this Axes space will be taken and used to plot a colormap, unless ``cbar``
#     is False or a separate Axes is provided to ``cbar_ax``.
#
#     Parameters
#     ----------
#     data : rectangular dataset
# ...

# %%
help(atr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-11cb15976c80> in <module>()
# ----> 1 help(atr)
#
# NameError: name 'atr' is not defined

# %%
1 Law 
2/4/10 Natural Science/Medical
3/9/11/13 Social Science
5 Engineering
6/7/16 Liberal Arts
8 Business/Finance
12/14/15/17/18 Arts

# %%
df_f.loc

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
import seaborn as sns
#sns.set()

# Load the example flights dataset and conver to long-form
#flights_long = sns.load_dataset("flights")
#flights_long
Fields = df_f.pivot("field_cd", "field_pcd", "match")
Fields

# Draw a heatmap with the numeric values in each cell
#sns.heatmap(Fields, annot=True, fmt="d", linewidths=.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-900aae907e15> in <module>()
#       7 #flights_long = sns.load_dataset("flights")
#       8 #flights_long
# ----> 9 Fields = df_f.pivot("field_cd", "field_pcd", "match")
#      10 Fields
#      11
#
# /Users/lexiewen/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    3844         """
#    3845         from pandas.core.reshape import pivot
# -> 3846         return pivot(self, index=index, columns=columns, values=values)
#    3847
#    3848     def stack(self, level=-1, dropna=True):
#
# /Users/lexiewen/anaconda/lib/python3.5/site-packages/pandas/core/reshape.py in pivot(self, index, columns, values)
#     330         indexed = Series(self[values].values,
#     331                          index=MultiIndex.from_arrays([index, self[columns]]))
# ...

# %%
import seaborn as sns
sns.set()

# Load the example flights dataset and conver to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5)

# %%
flights_long
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
flights
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
Cols = ['A', 'B', 'C', 'D']
df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-5a5b8df75bdd> in <module>()
#       1 Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
#       2 Cols = ['A', 'B', 'C', 'D']
# ----> 3 df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)
#       4
#       5 sns.heatmap(df)
#
# NameError: name 'DataFrame' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate Data
data=temp1.values
test=data.reshape(7,24)
#data = np.random.rand(7,24)
rows = df_train['hour'].unique()
columns = df_train['cday'].unique()

plt.pcolor(test,cmap=plt.cm.Reds)

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-53c87d308d76> in <module>()
#       3
#       4 # Generate Data
# ----> 5 data=temp1.values
#       6 test=data.reshape(7,24)
#       7 #data = np.random.rand(7,24)
#
# NameError: name 'temp1' is not defined

# %%
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

d = path.dirname(__file__)

# Read the whole text.
text = open(path.join(d, 'clinton.1.txt')).read()

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = imread(path.join(d, "alice_mask.png"))

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=STOPWORDS.add("said"))
# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "alice.png"))

# show
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-0a6ee14e535f> in <module>()
#       5 from wordcloud import WordCloud, STOPWORDS
#       6
# ----> 7 d = path.dirname(__file__)
#       8
#       9 # Read the whole text.
#
# NameError: name '__file__' is not defined
